# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack, ndimage
import math
from tqdm.notebook import tqdm
import seaborn as sns
import galsim
folder = 'data/FRBs_brifat_noise_normalized_centered_cropped8'
intensities = [300000, 100000, 80000, 60000]
durations = ['15ms', '15s']


for intens in intensities:
    
    plt.figure(figsize = (17,7))
    for idx in range(len(durations)):
        
        image = np.loadtxt(f'{folder}/FRB_FFT_{durations[idx]}_{intens}_11.txt')


        plt.subplot(1,2,idx+1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} FOB', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
folder = 'data/FRBs_brifat_noise_normalized_centered_notcropped'
intensities = [500000]
durations = ['15ms', '15s']


for intens in intensities:
    
    plt.figure(figsize = (17,7))
    for idx in range(len(durations)):
        
        image = np.loadtxt(f'{folder}/FRB_FFT_{durations[idx]}_{intens}_1500.txt')


        plt.subplot(1,2,idx+1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} FOB', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt
folder = 'data/FRBs_brifat_noise_normalized_centered_cropped8'
intensities = [300000, 100000, 80000, 60000]
durations = ['15ms', '15s']
durations_int = [0.015, 15]

for idx in range(len(durations)):
    plt.figure(figsize = (28,7))
    for idy, intens in enumerate(intensities):
        
        with open(f'fob_instance_{durations_int[idx]}s_{intens}.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
        image = image/sum(sum(image))
    
        
        plt.subplot(1,4,idy + 1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} - {intens} photons', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
for idx in range(len(durations)):
    plt.figure(figsize = (28,7))
    for idy, intens in enumerate(intensities):
        
        with open(f'fob_instance_{durations_int[idx]}s_{intens}_2.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
        image = image/sum(sum(image))
    
        
        plt.subplot(1,4,idy + 1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} - {intens} photons', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
for idx in range(len(durations)):
    plt.figure(figsize = (28,7))
    for idy, intens in enumerate(intensities):
        
        with open(f'fob_instance_{durations_int[idx]}s_{intens}_3.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
        image = image/sum(sum(image))
    
        
        plt.subplot(1,4,idy + 1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} - {intens} photons', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
intensities = [750000]
durations = ['15ms', '150ms', '15s']
durations_int = [0.015, 0.15, 15]
res = ['res1', '1mu']
ress = ['10 $\mu / pixel$', '1 $\mu / pixel$']

plt.figure(figsize = (28,14))
ids = 1

for idy, intens in enumerate(res):
    for idx in range(len(durations)):

        with open(f'fob_instance_{durations_int[idx]}s_750000_{res[idy]}_noeffect.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
    
        
        plt.subplot(2,3,ids)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        cbar.formatter.set_powerlimits((0, 0))
        cbar.set_label(label='ADU Counts',size=22)
        plt.rc('font', **{'size':'16'})
        plt.title(f'{durations[idx]} - {ress[idy]}', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()
        ids += 1
        
    plt.savefig('ImagesWithBF.png', dpi=300)

# %%
intensities = [750000]
durations = ['15ms']
durations_int = [0.015]
res = ['res1']
effects = ['No Brighter-Fatter', 'Brighter-Fatter']
# Remember that noeffect corresponds to brighter fatter effect, and effect corresponds to no effect

plt.figure(figsize = (16,6))
ids = 1

for idy, intens in enumerate(['effect', 'noeffect']):
    for idx in range(len(durations)):

        with open(f'fob_instance_0.015s_750000_res1_{intens}.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
    
        
        plt.subplot(1,2,ids)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 24)
        plt.ylabel('Position (pixels)', fontsize = 24)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.rc('font', **{'size':'16'})
        cbar.set_label(label='ADU Counts',size=22)
        cbar.formatter.set_powerlimits((0, 0))
        plt.title(f'{effects[idy]}', fontsize = 24)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()
        ids += 1

plt.savefig('brighterfatter.png', dpi=300)

# %%
for idx in range(len(durations)):
    plt.figure(figsize = (28,7))
    for idy, intens in enumerate(intensities):
        
        with open(f'fob_instance_{durations_int[idx]}s_{intens}_4.npy', 'rb') as f:
            image = np.load(f)

        image[image < 0] = 0
        image += 1000
        image_array = np.random.normal(loc = image, scale = np.sqrt(image))
        image = np.clip(image, 0, 1e5)
        image = image/sum(sum(image))
    
        
        plt.subplot(1,4,idy + 1)
        plt.imshow(image)
        plt.xlabel('Position (pixels)', fontsize = 28)
        plt.ylabel('Position (pixels)', fontsize = 28)
        plt.tick_params(labelsize = 22)
        cbar = plt.colorbar(fraction = 0.046, pad = 0.04)
        plt.title(f'{durations[idx]} - {intens} photons', fontsize = 28)
        cbar.ax.tick_params(labelsize = 22)

        plt.tight_layout()

# %%
def psd_avg(duration, num_phot, num_sim, noises = False):
    px = np.zeros((num_sim, 8))
    py = np.zeros((num_sim, 8))
    frequencies = np.zeros(8)
    noise = np.zeros(num_sim)

    for it in tqdm(range(0, num_sim)):
        if noises == True:
            image = np.loadtxt(f'data/noise/{it}.txt')
        else:
            image = np.loadtxt(f'data/FRBs_brifat_noise_normalized_centered_cropped8/FRB_FFT_{duration}_{num_phot}_{it}.txt')
        if image.shape[0] == 17:
            px[it], py[it], frequencies = psds(image)
            noise[it] = 10*np.log10(np.sum(image)/400)

    mean_x = np.median(px, axis = 0)
    var_x = np.var(px, axis = 0)

    mean_y = np.median(py, axis = 0)
    var_y = np.var(py, axis = 0)
    
    mean_noise = np.median(noise)*np.ones(11)
    var_noise = np.var(noise)*np.ones(11)
    
    return mean_x, var_x, mean_y, var_y, frequencies

def psds(image):
    
    # Round up the size along this axis to an even number
    n = int( math.ceil(image.shape[0] / 2.) * 2 )

    # We use rfft since we are processing real values
    a = np.fft.fftshift(np.fft.fft(image, n, axis = 0))
    psd_x = 20*np.log10(np.sum(abs(a), axis = 1)/a.shape[1])
    
    
    a = np.fft.fftshift(np.fft.fft(image, n, axis = 1))
    psd_y = 20*np.log10(np.sum(abs(a), axis = 0)/a.shape[0])

    # Generate a list of frequencies
    freqs = np.fft.fftshift(np.fft.fftfreq(n))
    
    
    return psd_x[10:], psd_y[10:], freqs[10:]

# %%
duration = '15s'
num_phot = 750000
cm = plt.cm.get_cmap('tab20')

plt.figure(figsize = (27,7))

plt.subplot(1,3,1)
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 4000)
plt.plot(frequencies, mean_x, 'o-', label='7.5e5 photons', color = cm.colors[0])
plt.fill_between(frequencies, mean_x - 1.95*var_x, mean_x + 1.95*var_x, color = cm.colors[1], alpha=.5)
plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)

num_phot = 300000
plt.subplot(1,3,2)
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='3e5 photons', color = cm.colors[4])
plt.fill_between(frequencies, mean_x - 1.95*var_x, mean_x + 1.95*var_x, color = cm.colors[5], alpha=.5)

plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)

num_phot = 80000
plt.subplot(1,3,3)
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='8e4 photons', color = cm.colors[8])
plt.fill_between(frequencies, mean_x - 1.95*var_x, mean_x + 1.95*var_x, color = cm.colors[9], alpha=.5)

num_phot = 20000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='2e4 photons', color = cm.colors[10])
plt.fill_between(frequencies, mean_x - 1.95*var_x, mean_x + 1.95*var_x, color = cm.colors[11], alpha=.5)


mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000, noises = True)
plt.plot(frequencies, mean_x, 'o-', label='Noise', color = cm.colors[12])
plt.fill_between(frequencies, mean_x - 1.95*var_x, mean_x + 1.95*var_x, color = cm.colors[13], alpha=.5)

plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (0.0, 0.46388888888888885)

# %%
plt.figure(figsize = (27,7))
cm = plt.cm.get_cmap('tab10')


duration = '15s'

plt.subplot(1,3,1)
num_phot = 750000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='8.80 Jy ms', color = cm.colors[0])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[0], capsize = 5, alpha = .75)

num_phot = 500000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='5.86 Jy ms', color = cm.colors[1])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[1], capsize = 5, alpha = .75)

num_phot = 100000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='1.17 Jy ms', color = cm.colors[2])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[2], capsize = 5, alpha = .75)

num_phot = 20000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='0.23 Jy ms', color = cm.colors[3])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[3], capsize = 5, alpha = .75)

mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000, noises = True)
plt.plot(frequencies, mean_x, 's-', label='Noise', color = cm.colors[4])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[4], capsize = 5, alpha = .75)

plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s steady source', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
#---------------------------------------
plt.subplot(1,3,2)
duration = '15ms'

num_phot = 750000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='8.80 Jy ms', color = cm.colors[0])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[0], capsize = 5, alpha = .75)

num_phot = 500000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004, mean_x, 'o-', label='5.86 Jy ms', color = cm.colors[1])
plt.errorbar(frequencies+ 0.004*1, mean_x, yerr = np.sqrt(var_x), color = cm.colors[1], capsize = 5, alpha = .75)


num_phot = 100000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004*2, mean_x, 'o-', label='1.17 Jy ms', color = cm.colors[2])
plt.errorbar(frequencies+ 0.004*2, mean_x, yerr = np.sqrt(var_x), color = cm.colors[2], capsize = 5, alpha = .75)

num_phot = 20000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.004*3, mean_x, 'o-', label='0.23 Jy ms', color = cm.colors[3])
plt.errorbar(frequencies+ 0.004*3, mean_x, yerr = np.sqrt(var_x), color = cm.colors[3], capsize = 5, alpha = .75)

mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000, noises = True)
plt.plot(frequencies, mean_x, 's-', label='Noise', color = cm.colors[4])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[4], capsize = 5, alpha = .75)


plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15ms FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)

# --------------------

plt.subplot(1,3,3)
cm = plt.cm.get_cmap('tab20')

num_phot = 750000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.009, mean_x, 's-', label='15s,  8.80 Jy ms', color = cm.colors[1])
plt.errorbar(frequencies+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[1], capsize = 5, alpha = .75)

duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label=f'15ms, 8.80 Jy ms', color = cm.colors[0])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[0], capsize = 5, alpha = .75)

num_phot = 500000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.004 + 0.009, mean_x, 's-', label='15s, 5.86 Jy ms', color = cm.colors[3])
plt.errorbar(frequencies+ 0.004+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[3], capsize = 5, alpha = .75)

duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004, mean_x, 'o-', label='15ms, 5.86 Jy ms', color = cm.colors[2])
plt.errorbar(frequencies+ 0.004, mean_x, yerr = np.sqrt(var_x), color = cm.colors[2], capsize = 5, alpha = .75)


num_phot = 100000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.008+ 0.009, mean_x, 's-', label='15s, 1.17 Jy ms', color = cm.colors[5])
plt.errorbar(frequencies+ 0.008+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[5], capsize = 5, alpha = .75)

duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.008, mean_x, 'o-', label='15ms, 1.17 Jy ms', color = cm.colors[4])
plt.errorbar(frequencies+ 0.008, mean_x, yerr = np.sqrt(var_x), color = cm.colors[4], capsize = 5, alpha = .75)


plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('Comparison 15s to 15ms', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
plt.savefig('PowerAnalysis.png', dpi = 300)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
duration = '15ms'
num_phot = 750000
cm = plt.cm.get_cmap('tab20')

plt.figure(figsize = (8,7))


mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 4000)
plt.plot(frequencies, mean_x, 'o-', label='7.5e5 photons', color = cm.colors[0])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[1], alpha=.5)

num_phot = 300000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='3e5 photons', color = cm.colors[4])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[5], alpha=.5)

num_phot = 80000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='8e4 photons', color = cm.colors[2])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[3], alpha=.5)

num_phot = 20000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='2e4 photons', color = cm.colors[6])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[7], alpha=.5)


mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000, noises = True)
plt.plot(frequencies, mean_x, 'o-', label='Noise', color = cm.colors[12])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[13], alpha=.5)

plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15ms FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (0.0, 0.46388888888888885)

# %%
duration = '15ms'
num_phot = 750000
cm = plt.cm.get_cmap('tab10')

plt.figure(figsize = (8,7))


mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='8.80 Jy ms', color = cm.colors[0])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[0], capsize = 5, alpha = .75)

num_phot = 500000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004, mean_x, 'o-', label='5.86 Jy ms', color = cm.colors[1])
plt.errorbar(frequencies+ 0.004*1, mean_x, yerr = np.sqrt(var_x), color = cm.colors[1], capsize = 5, alpha = .75)


num_phot = 100000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004*2, mean_x, 'o-', label='1.17 Jy ms', color = cm.colors[2])
plt.errorbar(frequencies+ 0.004*2, mean_x, yerr = np.sqrt(var_x), color = cm.colors[2], capsize = 5, alpha = .75)


num_phot = 20000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.004*3, mean_x, 'o-', label='0.23 Jy ms', color = cm.colors[3])
plt.errorbar(frequencies+ 0.004*3, mean_x, yerr = np.sqrt(var_x), color = cm.colors[3], capsize = 5, alpha = .75)

plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (0.0, 0.47648888888888885)

# %%
fluence = [8.80348476, 5.86898984, 3.5213939, 1.17379797, 0.93903837, 0.70427878, 0.46951919, 0.23475959]
cm = plt.cm.get_cmap('tab20')

plt.figure(figsize = (8,7))

num_phot = 750000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.009, mean_x, 's-', label='15s,  8.80 Jy ms', color = cm.colors[1])
plt.errorbar(frequencies+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[1], capsize = 5, alpha = .75)

duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label=f'15ms, 8.80 Jy ms', color = cm.colors[0])
plt.errorbar(frequencies, mean_x, yerr = np.sqrt(var_x), color = cm.colors[0], capsize = 5, alpha = .75)

num_phot = 500000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.004 + 0.009, mean_x, 's-', label='15s, 5.86 Jy ms', color = cm.colors[3])
plt.errorbar(frequencies+ 0.004+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[3], capsize = 5, alpha = .75)

duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.004, mean_x, 'o-', label='15ms, 5.86 Jy ms', color = cm.colors[2])
plt.errorbar(frequencies+ 0.004, mean_x, yerr = np.sqrt(var_x), color = cm.colors[2], capsize = 5, alpha = .75)


num_phot = 100000
duration = '15s'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies + 0.008+ 0.009, mean_x, 's-', label='15s, 1.17 Jy ms', color = cm.colors[5])
plt.errorbar(frequencies+ 0.008+ 0.009, mean_x, yerr = np.sqrt(var_x), color = cm.colors[5], capsize = 5, alpha = .75)


duration = '15ms'
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies+ 0.008, mean_x, 'o-', label='15ms, 1.17 Jy ms', color = cm.colors[4])
plt.errorbar(frequencies+ 0.008, mean_x, yerr = np.sqrt(var_x), color = cm.colors[4], capsize = 5, alpha = .75)



plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
# Out:
# ...
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (0.0, 0.4817388888888889)

# %%
duration = '15ms'
num_phot = 300000
cm = plt.cm.get_cmap('tab20')

plt.figure(figsize = (8,7))


mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='15ms, 6e4', color = cm.colors[0])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[1], alpha=.5)


duration = '15s'
num_phot = 300000
mean_x, var_x, mean_y, var_y, frequencies = psd_avg(duration, num_phot, 2000)
plt.plot(frequencies, mean_x, 'o-', label='15s, 6e4', color = cm.colors[2])
plt.fill_between(frequencies, mean_x - 0.674*var_x, mean_x + 0.674*var_x, color = cm.colors[3], alpha=.5)


plt.grid()
plt.tick_params(labelsize = 20)
plt.xlabel('Frequency ($px^{-1}$)', fontsize = 22)
plt.ylabel('Power Magnitude (dB)', fontsize = 22)
plt.title('15s FOB', fontsize = 22)
plt.legend(fontsize = 15)
plt.xlim(left = 0)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (2000, 17)
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (2000, 17)
# (0.0, 0.4888888888888889)
